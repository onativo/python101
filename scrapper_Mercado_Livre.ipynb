# %% [markdown]
# <a href="https://colab.research.google.com/github/onativo/python101/blob/main/scrapper_Mercado_Livre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

# %%
url_base = 'https://lista.mercadolivre.com.br/'

print('Quer comprar o quê?')
produto_name = input('Desejo comprar: ')
response = requests.get(url_base + produto_name)
site = BeautifulSoup(response.text, 'html.parser')
produtos = site.find_all('div', attrs={'class': 'andes-card andes-card--flat andes-card--default ui-search-result ui-search-result--core andes-card--padding-default'})
#produtos2 = site.find('div', attrs={'class': 'andes-card andes-card--flat andes-card--default ui-search-result ui-search-result--core andes-card--padding-default andes-card--animated'})
print('Ok, aqui está uma lista com ' + produto_name + ':\n\n')
#print(produtos2.prettify())

for produto in produtos:
  #produto_procurado
  titulo_prod = produto.find('h2', attrs={'class': 'ui-search-item__title'})
  link_prod = produto.find('a', attrs={'class': 'ui-search-link'})

  titulo_prod2 = produtos2.find('h2', attrs={'class': 'ui-search-item__title ui-search-item__group__element'})
  link_prod2 = produtos2.find('a', attrs={'class': 'ui-search-result__content ui-search-link'})

  #valor_produto
  moeda = produto.find('span', attrs={'class': 'price-tag-symbol'})
  real = produto.find('span', attrs={'class': 'price-tag-fraction'})
  #virgula = produto.find('span', attrs={'class': 'price-tag-decimal-separator'})
  cents = produto.find('span', attrs={'class': 'price-tag-cents'})

  #lista
  #print(produto.prettify())
  print('Título do produto: ' + titulo_prod.text)
  print('Link de compra: ' + link_prod['href'])
  if(cents):
    print('Valor do produto é: ' + moeda.text, real.text + ',' + cents.text)
  else:
    print('Valor do produto é: ' + moeda.text, real.text)
  print('\n\n')

#quadros
#print('Título do produto: ' + titulo_prod2.text)
#print('Link de compra: ' + link_prod2['href'])
#print('Valor do produto é: ' + moeda.text, real.text + ',' + cents.text)
#print('\n\n')
# Out:
# Quer comprar o quê?
# Desejo comprar: mi band 5
# Ok, aqui está uma lista com mi band 5:
#
#
# Título do produto: Xiaomi Mi Smart Band 5 1.1" caixa de  plástico pc  black pulseira  black de  elastômero termoplástico e liga de alumínio XMSH10HM
# Link de compra: https://www.mercadolivre.com.br/xiaomi-mi-smart-band-5-11-caixa-de-plastico-pc-black-pulseira-black-de-elastmero-termoplastico-e-liga-de-aluminio-xmsh10hm/p/MLB15963018?pdp_filters=category:MLB135384#searchVariation=MLB15963018&position=1&search_layout=stack&type=product&tracking_id=3371428d-be16-4103-8490-3c49a694d72c
# Valor do produto é: R$ 186,85
#
#
#
# Título do produto: Relogio Smartwatch Xiaomi Mi Band 5 + Pulseira + Pelicula M5
# Link de compra: https://produto.mercadolivre.com.br/MLB-1990354918-relogio-smartwatch-xiaomi-mi-band-5-pulseira-pelicula-m5-_JM?searchVariation=95392831745#searchVariation=95392831745&position=6&search_layout=stack&type=item&tracking_id=3371428d-be16-4103-8490-3c49a694d72c
# ...
